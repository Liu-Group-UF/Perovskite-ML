# %%
# train the model for material project data for predicting formation energy
# !python train.py  --csv_name 'mp_fm.csv'
# Out:
# num_parameters: 80065
# =====Epoch 1
# ...
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 24.00it/s]
# Saving checkpoint...
# {'Train': 1.9617894887924194, 'Validation': 5.0830464363098145, 'Test': 5.032925605773926, 'Best valid': 5.0830464363098145, 'Test@ best valid': 5.032925605773926, 'Duration': 1.0199224590032827}
# =====Epoch 2
# ...
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 23.55it/s]
# Saving checkpoint...
# {'Train': 1.421138095855713, 'Validation': 2.866122245788574, 'Test': 2.8872809410095215, 'Best valid': 2.866122245788574, 'Test@ best valid': 2.8872809410095215, 'Duration': 0.9868882080045296}
# =====Epoch 3
# ...
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 23.84it/s]
# Saving checkpoint...
# {'Train': 1.2764267325401306, 'Validation': 1.871924638748169, 'Test': 1.9572153091430664, 'Best valid': 1.871924638748169, 'Test@ best valid': 1.9572153091430664, 'Duration': 0.9459657499974128}
# =====Epoch 4
# ...
